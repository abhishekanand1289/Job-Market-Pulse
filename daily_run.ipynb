# %%
import subprocess
import sys

# %%
py = sys.executable

# %%
subprocess.run([py, "data_pull_job_posting.ipynb"])
subprocess.run([py, "load_to_database.ipynb"])
# Out:
# CompletedProcess(args=['C:\\Users\\ahishekanand\\AppData\\Local\\Programs\\Python\\Python311\\python.exe', 'load_to_database.ipynb'], returncode=1)
