# %%
import pandas as pd
import numpy as np
import mysql.connector

# %%
conn = mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',           
    password='@1289Royal',  
    database='job_postings')

# %%
cursor = conn.cursor()

# %%
df = pd.read_csv("C:/Users/ahishekanand/Desktop/Job Market Pulse/data/jobs_combined_20260711.csv")

# %%
df.shape
# Out:
# (2124, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124 entries, 0 to 2123
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   source              2124 non-null   object
#  1   search_keyword      2124 non-null   object
#  2   job_id              2124 non-null   object
#  3   title               2124 non-null   object
#  4   company             2117 non-null   object
#  5   department          489 non-null    object
#  6   location            1992 non-null   object
#  7   salary_min          965 non-null    float64
#  8   salary_max          965 non-null    float64
#  9   salary_interval     998 non-null    object
#  10  posted_date         1863 non-null   object
#  11  close_date          489 non-null    object
#  12  job_url             2124 non-null   object
#  13  job_summary         1162 non-null   object
#  14  work_schedule       559 non-null    object
#  15  position_type       58 non-null     object
#  16  security_clearance  489 non-null    object
#  17  remote              0 non-null      float64
#  18  collected_at        2124 non-null   object
# dtypes: float64(3), object(16)
# memory usage: 315.4+ KB

# %%
df.isna().sum()
# Out:
# source                   0
# search_keyword           0
# job_id                   0
# title                    0
# company                  7
# department            1635
# location               132
# salary_min            1159
# salary_max            1159
# salary_interval       1126
# posted_date            261
# close_date            1635
# job_url                  0
# job_summary            962
# work_schedule         1565
# position_type         2066
# security_clearance    1635
# remote                2124
# collected_at             0
# dtype: int64

# %%
df = df.replace({np.nan: None, 'nan': None, 'None': None, '': None})

# %%
for col in ['posted_date', 'close_date']:
    df[col] = df[col].apply(lambda x: x if x and x != 'nan' else None)

# %%
df.isnull().sum()
# Out:
# source                   0
# search_keyword           0
# job_id                   0
# title                    0
# company                  7
# department            1635
# location               132
# salary_min            1159
# salary_max            1159
# salary_interval       1126
# posted_date            261
# close_date            1635
# job_url                  0
# job_summary            962
# work_schedule         1565
# position_type         2066
# security_clearance    1635
# remote                2124
# collected_at             0
# dtype: int64

# %%
df.shape
# Out:
# (2124, 19)

# %%
df['location']      = df['location'].apply(lambda x: x[:500] if x else None)
df['work_schedule'] = df['work_schedule'].apply(lambda x: x[:50] if x else None)
df['position_type'] = df['position_type'].apply(lambda x: x[:50] if x else None)
df['company']       = df['company'].apply(lambda x: x[:300] if x else None)
df['title']         = df['title'].apply(lambda x: x[:200] if x else None)

# %%
insert_sql = """INSERT INTO postings (
    source, keyword, job_id, title, company, department,
    location, salary_min, salary_max, salary_interval,
    posted_date, close_date, job_url, job_summary,
    work_schedule, position_type, security_clearance, remote, collected_at
) VALUES (
    %(source)s, %(search_keyword)s, %(job_id)s, %(title)s,
    %(company)s, %(department)s, %(location)s,
    %(salary_min)s, %(salary_max)s, %(salary_interval)s,
    %(posted_date)s, %(close_date)s, %(job_url)s, %(job_summary)s,
    %(work_schedule)s, %(position_type)s, %(security_clearance)s,
    %(remote)s, %(collected_at)s
)
ON DUPLICATE KEY UPDATE
    title          = VALUES(title),
    salary_min     = VALUES(salary_min),
    salary_max     = VALUES(salary_max),
    job_summary    = VALUES(job_summary),
    collected_at   = VALUES(collected_at);"""

new_rows = 0
skipped  = 0

for record in df.to_dict("records"):
    try:
        cursor.execute(insert_sql, record)
        if cursor.rowcount == 1:
            new_rows += 1
        else:
            skipped += 1
    except Exception as e:
        print(f"Row skipped: {e}")

# %%
conn.commit()

# %%
df['title'].unique()
# Out:
# array(['Data Analyst', 'Program Analyst (Data Management)',
#        'Management and Program Analyst (Data Science)', ...,
#        'Analyst-Merchandising Operations',
#        'Business Operations Analyst, Technical Training',
#        'Analyst-Merchandising Operations – Pro Selling – Item Health (QA)'],
#       dtype=object)

# %%
new_rows
# Out:
# 44

# %%
skipped
# Out:
# 2080
